# %% [markdown]
# <a href="https://colab.research.google.com/github/youssssefff/LeetCode-DynamicPrograming/blob/main/bloodGlocuseipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import patoolib
patoolib.extract_archive("/content/brist1d.zip")
# Out:
# INFO patool: Extracting /content/brist1d.zip ...
# INFO:patool:Extracting /content/brist1d.zip ...
# INFO patool: running /usr/bin/7z x -o./Unpack_4uha2s0r -- /content/brist1d.zip
# INFO:patool:running /usr/bin/7z x -o./Unpack_4uha2s0r -- /content/brist1d.zip
# INFO patool:     with input=''
# INFO:patool:    with input=''
# INFO patool: ... /content/brist1d.zip extracted to `brist1d' (multiple files in root).
# INFO:patool:... /content/brist1d.zip extracted to `brist1d' (multiple files in root).
# 'brist1d'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras import layers, Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
dataset= pd.read_csv("/content/brist1d/train.csv")
dataset.head()
# Out:
# <ipython-input-3-558461e30f90>:1: DtypeWarning: Columns (435,436,437,438,439,440,441,442,443,444,445,446,447,448,449,450,451,452,453,454,455,456,457,458,459,460,461,462,463,464,465,466,467,468,469,470,471,472,473,474,475,476,477,478,479,480,481,482,483,484,485,486,487,488,489,490,491,492,493,494,495,496,497,498,499,500,501,502,503,504,505,506) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset= pd.read_csv("/content/brist1d/train.csv")
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# ...

# %%
def train_test_split_data(df, test_size, target):

    x = df.drop(target, axis=1)  # Features
    y = df[target]               # Target

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=42)

    return x_train, x_test, y_train, y_test

# %%
def scale_data(X_train, X_test, scaler_type='standard', columns=None):
    if columns is None:
        columns = X_train.select_dtypes(include=['float64', 'int64']).columns.tolist()

    X_train_scaled = X_train.copy()
    X_test_scaled = X_test.copy()

    if scaler_type == 'standard':
        scaler = StandardScaler()
    elif scaler_type == 'minmax':
        scaler = MinMaxScaler()
    elif scaler_type == 'robust':
        scaler = RobustScaler()
    else:
        raise ValueError("Invalid scaler_type. Choose from 'standard', 'minmax', 'robust'.")

    X_train_scaled[columns] = scaler.fit_transform(X_train[columns])
    X_test_scaled[columns] = scaler.transform(X_test[columns])

    return X_train_scaled, X_test_scaled

# %%
def NaN_preprocess(df, type = "zero"):
    if type == "zero":
      df.fillna(0, inplace=True)
    elif type == "mean":
      for column in df.columns:
        mean_value = df[column].mean()
        df[column].fillna(mean_value, inplace=True)
    elif type == "median":
      for column in df.columns:
        median_value = df[column].median()
        df[column].fillna(median_value, inplace=True)
    return df

# %%
def label_encode_dataframe(df, columns=None):

    df_encoded = df.copy()

    if columns is None:
        columns = df_encoded.select_dtypes(include=['object']).columns.tolist()

    for col in columns:
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col])

    return df_encoded

# %%
df = label_encode_dataframe(dataset)
df.head()
# Out:
#      id  p_num  time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# 0     0      0    74      NaN      NaN      9.6      NaN      NaN      9.7
# 1     1      0    77      NaN      NaN      9.7      NaN      NaN      9.2
# 2  1112      0    80      NaN      NaN      9.2      NaN      NaN      8.7
# 3  2223      0    83      NaN      NaN      8.7      NaN      NaN      8.4
# 4  3334      0    86      NaN      NaN      8.4      NaN      NaN      8.1
#
#    bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  activity-0:25  \
# 0      NaN  ...             21             21             21             21
# 1      NaN  ...             21             21             21             21
# 2      NaN  ...             21             21             21             21
# 3      NaN  ...             21             21             21             21
# 4      NaN  ...             21             21             21             21
#
# ...

# %%
df = NaN_preprocess(df,"median")
df.head()
# Out:
# <ipython-input-46-26aa9923ab8f>:11: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(median_value, inplace=True)
#      id  p_num  time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  bg-5:30  \
# 0     0      0    74      0.0      0.0      9.6      0.0      0.0      9.7
# 1     1      0    77      0.0      0.0      9.7      0.0      0.0      9.2
# 2  1112      0    80      0.0      0.0      9.2      0.0      0.0      8.7
# 3  2223      0    83      0.0      0.0      8.7      0.0      0.0      8.4
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split_data(df, 0.2, "bg+1:00")

# %%
x_train.head()
# Out:
#             id  p_num  time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 175765  167329      8   123      6.8      6.8      6.8      6.8      6.8
# 164992  155358      8    96      8.5      8.3      8.2      8.1      8.0
# 34462    37778      2   204     10.8     10.7     10.6     10.6     10.8
# 172586  163796      8   212      8.9      9.4     10.0     10.7     10.8
# 176352  167980      8   192      5.7      5.4      5.3      5.2      5.2
#
#         bg-5:30  bg-5:25  ...  activity-0:45  activity-0:40  activity-0:35  \
# 175765      6.8      6.9  ...             21             21             21
# 164992      8.1      8.0  ...             21             21             21
# 34462      10.9     11.0  ...             21             21             21
# 172586     11.1     11.0  ...             21             21             21
# 176352      5.1      5.2  ...             21             21             21
#
#         activity-0:30  activity-0:25  activity-0:20  activity-0:15  \
# ...

# %%
y_train.head()
# Out:
# 175765     6.6
# 164992     8.3
# 34462     10.3
# 172586     4.7
# 176352    10.8
# Name: bg+1:00, dtype: float64

# %%
x_train, x_test = scale_data(x_train, x_test, scaler_type='standard')
x_train.head()
# Out:
#               id     p_num      time   bg-5:55   bg-5:50   bg-5:45   bg-5:40  \
# 175765  1.543437  1.425394 -0.244409 -0.037024 -0.152371 -0.229690 -0.036991
# 164992  1.309238  1.425394 -0.570791  0.391900  0.248812  0.160492  0.291084
# 34462  -0.991088 -0.858777  0.734736  0.972208  0.890706  0.829376  0.921998
# 172586  1.474318  1.425394  0.831442  0.492823  0.543013  0.662155  0.947235
# 176352  1.556173  1.425394  0.589677 -0.314563 -0.526809 -0.647742 -0.440776
#
#          bg-5:35   bg-5:30   bg-5:25  ...  activity-0:45  activity-0:40  \
# 175765 -0.148830 -0.236336 -0.012039  ...       0.113222       0.113098
# 164992  0.171447  0.127369  0.265578  ...       0.113222       0.113098
# 34462   0.918761  0.910733  1.022715  ...       0.113222       0.113098
# 172586  0.918761  0.966687  1.022715  ...       0.113222       0.113098
# 176352 -0.575867 -0.711950 -0.441084  ...       0.113222       0.113098
#
#         activity-0:35  activity-0:30  activity-0:25  activity-0:20  \
# ...

# %%
x_train.head()
# Out:
#               id  p_num      time   bg-5:55   bg-5:50   bg-5:45   bg-5:40  \
# 175765  0.945238   1.00  0.428571  0.306306  0.282158  0.244604  0.306306
# 164992  0.877614   1.00  0.334495  0.382883  0.344398  0.294964  0.364865
# 34462   0.213403   0.25  0.710801  0.486486  0.443983  0.381295  0.477477
# 172586  0.925280   1.00  0.738676  0.400901  0.390041  0.359712  0.481982
# 176352  0.948916   1.00  0.668990  0.256757  0.224066  0.190647  0.234234
#
#          bg-5:35   bg-5:30   bg-5:25  ...  activity-0:45  activity-0:40  \
# 175765  0.274194  0.244604  0.310811  ...            1.0            1.0
# 164992  0.322581  0.291367  0.360360  ...            1.0            1.0
# 34462   0.435484  0.392086  0.495495  ...            1.0            1.0
# 172586  0.435484  0.399281  0.495495  ...            1.0            1.0
# 176352  0.209677  0.183453  0.234234  ...            1.0            1.0
#
#         activity-0:35  activity-0:30  activity-0:25  activity-0:20  \
# ...

# %%
def regression_accuracy(y_true, y_pred, tolerance=0.1):
    # Calculate the absolute percentage difference between true and predicted values
    percentage_diff = tf.abs((y_true - y_pred) / y_true)
    # Check if the difference is within the specified tolerance (e.g., 10%)
    accurate = tf.less_equal(percentage_diff, tolerance)
    # Return the mean of accurate predictions, ensuring the result does not exceed 100%
    return tf.reduce_mean(tf.cast(accurate, tf.float32)) * 100.0

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras import regularizers

model = Sequential([
    Dense(2048, activation='relu', input_shape=(x_train.shape[1],)),
    Dense(1024, activation='relu',),
    Dense(512, activation='relu',),
    Dense(256, activation='relu', ),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1)  # Output layer for regression
])


# Compile the model
optimizer = Adam(learning_rate=0.0001)  # Adjust learning rate as needed
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[regression_accuracy])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit(x_train, y_train, epochs=50, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 4.0837 - regression_accuracy: 36.8481 - val_loss: 4.2003 - val_regression_accuracy: 35.7533
# Epoch 2/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 3.5626 - regression_accuracy: 38.8481 - val_loss: 3.9398 - val_regression_accuracy: 38.6329
# Epoch 3/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 16s 4ms/step - loss: 3.1278 - regression_accuracy: 40.8899 - val_loss: 3.7248 - val_regression_accuracy: 39.4669
# Epoch 4/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 2.7191 - regression_accuracy: 43.4524 - val_loss: 3.5830 - val_regression_accuracy: 41.3696
# Epoch 5/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 2.3358 - regression_accuracy: 46.1689 - val_loss: 3.4687 - val_regression_accuracy: 41.6491
# Epoch 6/50
# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 15s 3ms/step - loss: 1.9812 - regression_accuracy: 49.3083 - val_loss: 3.3883 - val_regression_accuracy: 41.6195
# Epoch 7/50
# ...

# %%
# ==> Nan to zero

# loss = 3.8210 accuracy = 37.8675

# minmax Scale -> standard Scale

# loss = 2.0454 accuracy 49.5382

# ==> lr = 0.001

# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 14s 3ms/step - loss: 2.0667 - regression_accuracy: 48.9129

# lr = 0.001 -> lr = 0.01

# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 4.2873 - regression_accuracy: 34.7259

# lr = 0.01 -> lr = 0.0001

# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 1.9117 - regression_accuracy: 49.6254

# => model arch update

# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 1.5519 - regression_accuracy: 54.1599

# => more model arch update

# 4426/4426 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.6875 - regression_accuracy: 52.6653

# epochs 10 => , 20

# 3541/3541 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 0.8086 - regression_accuracy: 52.0725 - val_loss: 3.4667 - val_regression_accuracy: 43.1292

# NaN to median

# 3541/3541 ━━━━━━━━━━━━━━━━━━━━ 20s 3ms/step - loss: 1.6546 - regression_accuracy: 52.9680 - val_loss: 3.9001 - val_regression_accuracy: 39.0131

# => model arch update

# 3541/3541 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - loss: 1.4527 - regression_accuracy: 55.9877 - val_loss: 3.4291 - val_regression_accuracy: 41.2881
